# %% [markdown]
# #Installs

# %%
# !git clone https://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@github.com/Reouth/personalized-event-classification.git
# %pip install -qq git+https://github.com/huggingface/diffusers.git
# %pip install -q accelerate
# !pip install bitsandbytes
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# Cloning into 'personalized-event-classification'...
# remote: Enumerating objects: 670, done.
# remote: Counting objects: 100% (302/302), done.
# remote: Compressing objects: 100% (186/186), done.
# remote: Total 670 (delta 168), reused 169 (delta 104), pack-reused 368 (from 1)
# Receiving objects: 100% (670/670), 254.22 KiB | 5.19 MiB/s, done.
# Resolving deltas: 100% (394/394), done.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %% [markdown]
# # Imports

# %%
import os
import pandas as pd
os.chdir('/content/personalized-event-classification')

import helper_functions
import data_upload
import similarity_calc

# %% [markdown]
# #login access drive

# %%
#@title connect to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # upload csvs

# %%
#@title upload csvs
csvs = []
csvs_folder = "/content/drive/MyDrive/thesis_OO_SD/ex_machina/csv_results/red_filter/CLIP_imagic_embeds/a_red_filtered_photo"
csvs = data_upload.upload_csvs(csvs_folder)
results_folder = '/content/drive/MyDrive/thesis_OO_SD/ex_machina/similarity_results/red_filter/a_red_filtered_photo/CLIP_imagic_embeds'
os.makedirs(results_folder, exist_ok=True)
clip_csv=True

# %% [markdown]
# #top_k results

# %%
avg=False
k_range = range(1,4,1)
pred_column ='cls_predicted'

results =similarity_calc.csv_to_topk_results(avg,clip_csv,k_range,csvs,pred_column,results_folder)

# %% [markdown]
# # mAP calculation

# %%
ap_results, mean_ap = similarity_calc.calculate_average_precision(csvs_folder, results_folder, clip_csv=clip_csv)
print(f'AP results: {ap_results}')
print(f'Mean Average Precision (mAP): {mean_ap:.4f}')
# Out:
# Processing ava class...
# Processing caleb class...
# Processing kyoto class...
# Processing nathan class...
# AP results: {'ava': 1.0, 'caleb': 1.0, 'kyoto': 0.6666666666666666, 'nathan': 1.0}
# Mean Average Precision (mAP): 0.9167

# %% [markdown]
# #move to all csv folder

# %%
source_folder = '/content/drive/MyDrive/thesis_OO_SD/ex_machina/similarity_results/red_filter'
destintion_folder = '/content/drive/MyDrive/thesis_OO_SD/ex_machina/similarity_results/red_filter_all'
helper_functions.move_csv_files(source_folder,destintion_folder)
# Out:
# Moved: top_1_avg_accuracy_results.csv to /content/drive/MyDrive/thesis_OO_SD/ex_machina/similarity_results/red_filter_all/red_filter_a_red_filtered_photo_of_a_person_CLIP_SD_embeds
# Moved: top_2_avg_accuracy_results.csv to /content/drive/MyDrive/thesis_OO_SD/ex_machina/similarity_results/red_filter_all/red_filter_a_red_filtered_photo_of_a_person_CLIP_SD_embeds
# Moved: top_3_avg_accuracy_results.csv to /content/drive/MyDrive/thesis_OO_SD/ex_machina/similarity_results/red_filter_all/red_filter_a_red_filtered_photo_of_a_person_CLIP_SD_embeds
# Moved: top_1__accuracy_results.csv to /content/drive/MyDrive/thesis_OO_SD/ex_machina/similarity_results/red_filter_all/red_filter_a_red_filtered_photo_of_a_person_CLIP_SD_embeds
# Moved: top_2__accuracy_results.csv to /content/drive/MyDrive/thesis_OO_SD/ex_machina/similarity_results/red_filter_all/red_filter_a_red_filtered_photo_of_a_person_CLIP_SD_embeds
# ...

# %% [markdown]
# # compare all csv classes togerther

# %%
folder_path = '/content/drive/MyDrive/thesis_OO_SD/ex_machina/similarity_results/red_filter_all'
output_folder = '/content/drive/MyDrive/thesis_OO_SD/ex_machina/similarity_results/red_filter_merged_20'
os.makedirs(output_folder, exist_ok=True)
folders_names= list(os.listdir(folder_path))
folders_names

similarity_calc.merge_csv_results(folder_path,folders_names,output_folder)
# Out:
# /content/personalized-event-classification/similarity_calc.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['folder_name'] = folder  # Add the folder name as a new column
# /content/personalized-event-classification/similarity_calc.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row['folder_name'] = folder  # Add the folder name as a new column
# /content/personalized-event-classification/similarity_calc.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
